# %% [markdown]
# # Como instalar um Módulo/Biblioteca que não tenha no seu computador
#
# ### Estrutura:
#
# - Usaremos o "pip" para isso. É um gerenciador de módulos/pacotes/bibliotecas que ajuda a gente a instalar, atualizar, desinstalar novos módulos
# - Não precisa dominar pip, apenas os comandos que vamos usar aqui mesmo
#
# Passo 1: Abrir o Prompt do Anaconda<br>
# Passo 2: Instalar com o pip os pacotes que quiser<br>
# Passo 3: Reiniciar o Jupyter (nem sempre necessário, mas na dúvida é melhor fazer)<br>

# %%
import keyboard

keyboard.press_and_release('ctrl+t')

keyboard.write('hashtagtreinamentos.com')

keyboard.press_and_release('enter')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import keyboard
#       3 keyboard.press_and_release('ctrl+t')
#       5 keyboard.write('hashtagtreinamentos.com')
#
# File ~/Library/Python/3.9/lib/python/site-packages/keyboard/__init__.py:126
#     124     from. import _nixkeyboard as _os_keyboard
#     125 elif _platform.system() == 'Darwin':
# --> 126     from. import _darwinkeyboard as _os_keyboard
#     127 else:
#     128     raise OSError("Unsupported platform '{}'".format(_platform.system()))
#
# File ~/Library/Python/3.9/lib/python/site-packages/keyboard/_darwinkeyboard.py:3
#       1 import ctypes
#       2 import ctypes.util
# ----> 3 import Quartz
#       4 import time
#       5 import os
#
# File ~/Library/Python/3.9/lib/python/site-packages/Quartz/__init__.py:47
#      43     globals()["__dir__"] = dir_func
#      44     globals()["__getattr__"] = getattr_func
# ---> 47 globals().pop("_setup")()
#
# File ~/Library/Python/3.9/lib/python/site-packages/Quartz/__init__.py:10, in _setup()
#       7 import AppKit
#       8 import objc
# ---> 10 from . import (
#      11     CoreGraphics,
#      12     ImageIO,
#      13     ImageKit,
#      14     CoreVideo,
#      15     QuartzCore,
#      16     PDFKit,
#      17     QuartzFilters,
#      18     QuickLookUI,
#      19     QuartzComposer,
#      20 )
#      22 dir_func, getattr_func = objc.createFrameworkDirAndGetattr(
#      23     name="Quartz",
#      24     frameworkIdentifier=None,
#    (...)
#      40     metadict={},
#      41 )
#      43 globals()["__dir__"] = dir_func
#
# File ~/Library/Python/3.9/lib/python/site-packages/Quartz/CoreGraphics/__init__.py:80
#      76     kCGColorSpaceUserRGB = "kCGColorSpaceUserRGB"
#      77     kCGColorSpaceUserCMYK = "kCGColorSpaceUserCMYK"
# ---> 80 globals().pop("_setup")()
#
# File ~/Library/Python/3.9/lib/python/site-packages/Quartz/CoreGraphics/__init__.py:15, in _setup()
#      13 import objc
#      14 import os
# ---> 15 from . import (
#      16     _metadata,
#      17     _callbacks,
#      18     _doubleindirect,
#      19     _sortandmap,
#      20     _coregraphics,
#      21     _contextmanager,
#      22 )
#      23 from ._inlines import _inline_list_
#      25 if os.path.exists("/System/Library/Frameworks/CoreGraphics.framework"):
#
# ImportError: dlopen(/Users/emirfadul/Library/Python/3.9/lib/python/site-packages/Quartz/CoreGraphics/_callbacks.cpython-39-darwin.so, 0x0002): symbol not found in flat namespace (_CGDisplayRegisterReconfigurationCallback)
