# %% [markdown]
# ## Tempo até o próximo ano
#
# Crie um script Python que calcula quantos dias, horas, minutos e segundos faltam até o próximo Ano Novo.

# %% [markdown]
# Lembrar da tupla de struct_time: https://docs.python.org/3/library/time.html#time.struct_time

# %%
# lembrando

segundos_por_minuto = 60
segundos_por_hora = 60 * 60
segundos_por_dia = 24 * 60 * 60

print(f"Segundos em um minuto: {segundos_por_minuto} s")
print(f"Segundos em uma hora: {segundos_por_hora} s")
print(f"Segundos em um dia: {segundos_por_dia} s")
# Out:
# Segundos em um minuto: 60 s
# Segundos em uma hora: 3600 s
# Segundos em um dia: 86400 s

# %% [markdown]
# Lembrando de divisão:
#
# ![divisao](https://escolaeducacao.com.br/wp-content/uploads/2020/01/algoritmo-divisao.png)

# %%
import time


tempo_atual = time.localtime()
print(tempo_atual)
# Out:
# time.struct_time(tm_year=2025, tm_mon=8, tm_mday=12, tm_hour=12, tm_min=12, tm_sec=11, tm_wday=1, tm_yday=224, tm_isdst=0)

# %%
print(tempo_atual.tm_year)
# Out:
# 2025

# %%
tempo_ano_novo = (tempo_atual.tm_year + 1)
print(tempo_ano_novo)
# Out:
# 2026

# %%
segundos_restantes = int(time.mktime(tempo_ano_novo) - time.mktime(tempo_atual))
print(segundos_restantes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 segundos_restantes = int(time.mktime(tempo_ano_novo) - time.mktime(tempo_atual))
#       2 print(segundos_restantes)
#
# TypeError: Tuple or struct_time argument required

# %%
120 / segundos_por_minuto
# Out:
# 2.0

# %%
print(divmod(130,segundos_por_minuto))
# Out:
# (2, 10)

# %%
resultado, resto = divmod(130, segundos_por_minuto)
print(resultado)
print(resto)
# Out:
# 2
# 10

# %%
dias, resto_segundos = divmod(segundos_restantes, segundos_por_dia)
print(dias)
print(resto_segundos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 dias, resto_segundos = divmod(segundos_restantes, segundos_por_dia)
#       2 print(dias)
#       3 print(resto_segundos)
#
# NameError: name 'segundos_restantes' is not defined

# %%
horas, resto_segundos = divmod(segundos_restantes, segundos_por_dia)
minutos, segundos = divmod(resto_segundos, segundos_por_minuto)

print(horas)
print(minutos)
print(segundos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 horas, resto_segundos = divmod(segundos_restantes, segundos_por_dia)
#       2 minutos, segundos = divmod(resto_segundos, segundos_por_minuto)
#       4 print(horas)
#
# NameError: name 'segundos_restantes' is not defined
