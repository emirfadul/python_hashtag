# %% [markdown]
# # pandas lendo csv da internet
#
# ### Essa é uma das formas de importar arquivos da internet, direto do pandas. Mas nem sempre você vai conseguir abrir assim direto.
#
# ### 2 situações principais em que você consegue fazer direto
#
# 1. Arquivo csv direto no link (melhor dos mundos)
# 2. O arquivo csv é gerado para você, mas fica no meio de uma requisição que precisa ser tratada.

# %% [markdown]
# ### Caso 1: csv direto no link
#
# - Criei um arquivo csv e disponibilizei o link para download no Drive: https://drive.google.com/uc?authuser=0&id=1Ru7s-x3YJuStZK1mqr_qNqiHVvdHUN66&export=download

# %%
# Install pandas if not already installed
#%pip install pandas

import pandas as pd # type: ignore

url = 'https://drive.google.com/uc?authuser=0&id=1Ru7s-x3YJuStZK1mqr_qNqiHVvdHUN66&export=download'

cotacao_df = pd.read_csv(url)

display(cotacao_df)
# Out:
#               Date   Price    Open    High     Low Change %
# 0     Jan 01, 2020  4.0195  4.0195  4.0195  4.0195    0.00%
# 1     Dec 31, 2019  4.0195  4.0201  4.0201  4.0195    0.00%
# 2     Dec 30, 2019  4.0195  4.0484  4.0484  4.0084   -0.65%
# 3     Dec 27, 2019  4.0460  4.0568  4.0614  4.0339   -0.25%
# 4     Dec 26, 2019  4.0560  4.0827  4.0827  4.0453   -0.68%
# ...            ...     ...     ...     ...     ...      ...
# 3908  Jan 07, 2005  2.7120  2.7230  2.7290  2.6890   -0.36%
# 3909  Jan 06, 2005  2.7218  2.7140  2.7340  2.7060    0.27%
# 3910  Jan 05, 2005  2.7145  2.6980  2.7331  2.6910   -0.17%
# 3911  Jan 04, 2005  2.7190  2.6720  2.7230  2.6720    1.61%
# 3912  Jan 03, 2005  2.6759  2.6610  2.6760  2.6520    0.75%
#
# [3913 rows x 6 columns]

# %% [markdown]
# ### Caso 2: csv em uma requisição que precisa ser tratada
#
# Pesquisei por histórico de preços do café no Google e cheguei nesse site: https://portalweb.cooxupe.com.br:9080/portal/precohistoricocafe_2.jsp

# %%
# Install requests if not already installed
#%pip install requests

import pandas as pd
import requests
import io

url2 = 'https://portalweb.cooxupe.com.br:9080/portal/precohistoricocafe_2.jsp'

conteudo_url2 = requests.get(url2).content
print (conteudo_url2)
arquivo = io.StringIO(conteudo_url2.decode('latin1'))
cotacao_df2 = pd.read_csv(arquivo, sep=r'\r\n', engine='python')
display(cotacao_df2)
# Out:
# b'\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<link rel="stylesheet" href="css/screen.css" type="text/css" media="screen, print" />  \r\n<meta http-equiv="content-type" content="text/html; charset=ISO-8859-1" />\r\n<html lang="pt">\r\n    <head>\r\n        \r\n        <title>Pre\xe7o Hist\xf3rico do Caf\xe9</title>\r\n    </head>\r\n    <body>\r\n   \r\n        \r\n         <div id="body">\r\n                     \r\n        <h2>Pre\xe7o M\xe9dio das Sacas de Caf\xe9 comercializado na Cooxup\xe9 em R$</h2> \r\n        \n<table id="QueryFor1" class="display">\n<thead>\n<tr>\n<th>Ano</th>\n<th>Janeiro</th>\n<th>Fevereiro</th>\n<th>Mar\xe7o</th>\n<th>Abril</th>\n<th>Maio</th>\n<th>Junho</th>\n<th>Julho</th>\n<th>Agosto</th>\n<th>Setembro</th>\n<th>Outubro</th>\n<th>Novembro</th>\n<th>Dezembro</th></tr></thead>\n<tbody>\n<tr class="odd">\n<td>2025</td>\n<td class="r">\r\n                2256.79 </td>\n<td class="r">\r\n                2564.1 </td>\n<td class="r">\r\n                2554.43 </td>\n<td class="r">\r\n                2564.42 </td>\n<td class="r">\r\n                2382.57 </td>\n<td class="r">\r\n                2152.81 </td>\n<td class="r">\r\n                 </td>\n<td class="r">\r\n                 </td>\n<td class="r">\r\n                 </td>\n<td class="r">\r\n                 </td>\n<td class="r">\r\n                 </td>\n<td class="r">\r\n                 </td></tr>\n<tr class="even">\n<td>2024</td>\n<td class="r">\r\n                974.46 </td>\n<td class="r">\r\n                1005.54 </td>\n<td class="r">\r\n                1023.45 </td>\n<td class="r">\r\n                1145.12 </td>\n<td class="r">\r\n                1186.17 </td>\n<td class="r">\r\n                1240.85 </td>\n<td class="r">\r\n                1216.35 </td>\n<td class="r">\r\n                1279.77 </td>\n<td class="r">\r\n                1316.36 </td>\n<td class="r">\r\n                1463.25 </td>\n<td class="r">\r\n                1732.67 </td>\n<td class="r">\r\n                2063.69 </td></tr>\n<tr class="odd">\n<td>2023</td>\n<td class="r">\r\n                1030.14 </td>\n<td class="r">\r\n                1130.26 </td>\n<td class="r">\r\n                1103.37 </td>\n<td class="r">\r\n                1115.24 </td>\n<td class="r">\r\n                1030.64 </td>\n<td class="r">\r\n                927.88 </td>\n<td class="r">\r\n                878.5 </td>\n<td class="r">\r\n                868.24 </td>\n<td class="r">\r\n                802.59 </td>\n<td class="r">\r\n                800.95 </td>\n<td class="r">\r\n                845.6 </td>\n<td class="r">\r\n                925.46 </td></tr>\n<tr class="even">\n<td>2022</td>\n<td class="r">\r\n                1480.49 </td>\n<td class="r">\r\n                1488.11 </td>\n<td class="r">\r\n                1258.22 </td>\n<td class="r">\r\n                1253.25 </td>\n<td class="r">\r\n                1259.21 </td>\n<td class="r">\r\n                1256.28 </td>\n<td class="r">\r\n                1119.45 </td>\n<td class="r">\r\n                1075.91 </td>\n<td class="r">\r\n                1098.56 </td>\n<td class="r">\r\n                1032.75 </td>\n<td class="r">\r\n                915.26 </td>\n<td class="r">\r\n                994.22 </td></tr>\n<tr class="odd">\n<td>2021</td>\n<td class="r">\r\n                639.23 </td>\n<td class="r">\r\n                695.33 </td>\n<td class="r">\r\n                726.88 </td>\n<td class="r">\r\n                744.05 </td>\n<td class="r">\r\n                811.06 </td>\n<td class="r">\r\n                793.67 </td>\n<td class="r">\r\n                762.36 </td>\n<td class="r">\r\n                772.03 </td>\n<td class="r">\r\n                851.11 </td>\n<td class="r">\r\n                1113.29 </td>\n<td class="r">\r\n                1285.94 </td>\n<td class="r">\r\n                1446.66 </td></tr>\n<tr class="even">\n<td>2020</td>\n<td class="r">\r\n                501.68 </td>\ ...
#      <link rel="stylesheet" href="css/screen.css" type="text/css" media="screen, print" />
# 0     <meta http-equiv="content-type" content="text/...
# 1                                      <html lang="pt">
# 2                                                <head>
# 3                <title>Preço Histórico do Café</title>
# 4                                               </head>
# ...                                                 ...
# 1194  10055.01 </td></tr></tbody></table><div class=...
# 1195  <a href="/portal/precohistoricocafe_2.jsp;jses...
# 1196                                             </div>
# 1197                                            </body>
# 1198                                            </html>
#
# [1199 rows x 1 columns]

# %% [markdown]
# ### Apenas para lembrar os tipos de encoding principais que vamos usar:
#
# - encoding='latin1'
# - encoding='ISO-8859-1'
# - encoding='utf-8'
# - encoding='cp1252'
